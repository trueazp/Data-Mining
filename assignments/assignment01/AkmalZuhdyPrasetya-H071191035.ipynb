# %% [markdown]
# <h1><center>TUGAS PERTEMUAN II</center></h1>
# <h1><center>Akmal Zuhdy Prasetya (H071191035)</center></h1>

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 1. Import Dataset
#
# ### Sumber Dataset : https://www.kaggle.com/mguzmann/swedishcrime

# %%
df = pd.read_csv("D:\Kuliah\Semester_5\Pengantar Data Mining\datasets\swedish_crimes_1950-2015.csv")
df.head()
# Out:
#    Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 0  1950          2784               2306            120       1      105
# 1  1951          3284               2754            125       1      109
# 2  1952          3160               2608            119       1      104
# 3  1953          2909               2689            119       1      105
# 4  1954          3028               2791            126       1      107
#
#    sexual.offenses  rape  stealing.general  burglary  ...  vehicle.theft  \
# 0               40     5              1578       295  ...            NaN
# 1               45     6              1899       342  ...            NaN
# 2               39     4              1846       372  ...            NaN
# 3               45     5              1929       361  ...            NaN
# 4               41     5              1981       393  ...            NaN
#
#    out.of.vehicle.theft  shop.theft  robbery  fraud  criminal.damage  \
# ...

# %% [markdown]
# # 2. Penjelasan Dataset
#
# ### Dataset ini berisi data statistik tentang jumlah kejahatan yang dilaporkan di Swedia dari tahun 1950 sampai pada tahun 2015. Kolom-kolom yang terdapat di dalam dataset ini dapat dilihat di bagian di bawah ini.

# %%
df.columns
# Out:
# Index(['Year', 'crimes.total', 'crimes.penal.code', 'crimes.person', 'murder',
#        'assault', 'sexual.offenses', 'rape', 'stealing.general', 'burglary',
#        'house.theft', 'vehicle.theft', 'out.of.vehicle.theft', 'shop.theft',
#        'robbery', 'fraud', 'criminal.damage', 'other.penal.crimes',
#        'narcotics', 'drunk.driving', 'population'],
#       dtype='object')

# %% [markdown]
# # 3. Beberapa Contoh Visualisasi Konten Dataset

# %% [markdown]
# ## 3.1 Mengakses kolom

# %%
df['fraud']
# Out:
# 0      209
# 1      310
# 2      217
# 3      209
# 4      236
#       ...
# 61    1220
# 62    1356
# 63    1545
# 64    1610
# 65    1896
# Name: fraud, Length: 66, dtype: int64

# %% [markdown]
# ## 3.2 Menampilkan nilai rata-rata pada kolom tersebut

# %%
df.loc[:, 'fraud'].mean()
# Out:
# 730.6363636363636

# %% [markdown]
# ## 3.3 Mengakses kolom dengan kondisi tertentu kemudian menampilkan hasilnya hanya dengan kolom yang dipilih

# %%
df.loc[(df.rape > 50) & (df.robbery < 100), ['Year', 'rape', 'robbery']]
# Out:
#     Year  rape  robbery
# 57  2007    52       95
# 58  2008    59       97
# 60  2010    64       98
# 62  2012    66       97
# 63  2013    63       87
# 64  2014    69       86
# 65  2015    60       86

# %% [markdown]
# ## 3.4 Menampilkan data berdasarkan jangkauan baris yang diinginkan

# %%
df.loc[5:13, ['Year', 'sexual.offenses']]
# Out:
#     Year  sexual.offenses
# 5   1955               44
# 6   1956               38
# 7   1957               36
# 8   1958               40
# 9   1959               47
# 10  1960               54
# 11  1961               53
# 12  1962               49
# 13  1963               49

# %% [markdown]
# ## 3.5 Menambahkan kolom data baru dan mengisi kontennya berdasarkan kondisi tertentu

# %%
df.loc[(df.assault >= 100) & (df.assault < 200), ['year_title']] = 'yay'
df
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 0   1950          2784               2306            120       1      105
# 1   1951          3284               2754            125       1      109
# 2   1952          3160               2608            119       1      104
# 3   1953          2909               2689            119       1      105
# 4   1954          3028               2791            126       1      107
# ..   ...           ...                ...            ...     ...      ...
# 61  2011         14988              12267           1005       2      947
# 62  2012         14734              12148            974       2      914
# 63  2013         14603              12072            896       3      837
# 64  2014         14890              12305            923       3      859
# 65  2015         15342              12803            932       3      868
#
#     sexual.offenses  rape  stealing.general  burglary  ...  \
# ...

# %% [markdown]
# ## 3.6 Mengakses baris tertentu

# %%
df.iloc[22]
# Out:
# Year                       1972
# crimes.total               8509
# crimes.penal.code          7371
# crimes.person               242
# murder                        1
# assault                     223
# sexual.offenses              32
# rape                          7
# stealing.general           5535
# burglary                   1568
# house.theft               200.0
# vehicle.theft             426.0
# out.of.vehicle.theft      849.0
# shop.theft                335.0
# robbery                      25
# fraud                       592
# criminal.damage             456
# other.penal.crimes         1138
# narcotics                 235.0
# drunk.driving               223
# population              8122000
# year_title                  NaN
# Name: 22, dtype: object

# %% [markdown]
# # 4.  Deskripsi Statistik Dataset

# %%
df.describe(include='all')
# Out:
#                Year  crimes.total  crimes.penal.code  crimes.person  \
# count     66.000000     66.000000          66.000000      66.000000
# unique          NaN           NaN                NaN            NaN
# top             NaN           NaN                NaN            NaN
# freq            NaN           NaN                NaN            NaN
# mean    1982.500000  10084.257576        8695.181818     451.287879
# std       19.196354   4223.893287        3582.148938     295.041002
# min     1950.000000   2784.000000        2306.000000     119.000000
# 25%     1966.250000   6152.500000        5336.000000     185.250000
# 50%     1982.500000  11654.000000        9637.000000     370.500000
# 75%     1998.750000  13663.750000       12002.500000     690.500000
# max     2015.000000  15342.000000       12803.000000    1005.000000
#
#            murder     assault  sexual.offenses       rape  stealing.general  \
# ...

# %% [markdown]
# ## 4.1  Deskripsi Statistik Dataset tentang tingkat kejahatan di Swedia dari tahun 1950-2015 dalam diagram batang horizontal

# %%
df.plot(x="Year", y="crimes.total", kind="barh", rot=5, fontsize=18,  figsize=(40, 40))
# Out:
# <AxesSubplot:ylabel='Year'>

# %% [markdown]
# ## 4.2  Deskripsi Statistik Dataset tentang tingkat kejahatan di Swedia dari tahun 1950-2015 dalam diagram pie

# %%
df.plot(x="Year", y="crimes.total", kind="pie", rot=5, fontsize=18,  figsize=(40, 40))
# Out:
# <AxesSubplot:ylabel='crimes.total'>
